# %% [markdown]
# # 98. ドメイン適応
# Japanese-English Subtitle Corpus (JESC)やJParaCrawlなどの翻訳データを活用し，KFTTのテストデータの性能向上を試みよ．

# %% [markdown]
# ## GPU prepare
# 1. 使用可能GPUの確認
# 2. GPUの指定
# 3. PyTorchで利用できるGPU数の確認

# %%
# 使用可能GPUの確認
# !nvidia-smi
# Out:
# Sat Aug  6 09:06:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A6000    On   | 00000000:01:00.0 Off |                  Off |
# | 30%   33C    P8    24W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A6000    On   | 00000000:25:00.0 Off |                  Off |
# | 30%   50C    P8    28W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A6000    On   | 00000000:41:00.0 Off |                  Off |
# | 30%   30C    P8    30W / 300W |      8MiB / 48685MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A6000    On   | 00000000:61:00.0 Off |                  Off |
# | 30%   29C    P8    19W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A6000    On   | 00000000:81:00.0 Off |                  Off |
# | 30%   29C    P8    18W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A6000    On   | 00000000:A1:00.0 Off |                  Off |
# | 30%   28C    P8    18W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A6000    On   | 00000000:C1:00.0 Off |                  Off |
# | 30%   29C    P8    15W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A6000    On   | 00000000:E1:00.0 Off |                  Off |
# | 30%   28C    P8    14W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# GPUの指定
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1' #0番を使用するとき

# %%
# 確認
import torch
print(torch.cuda.device_count()) #Pytorchで使用できるGPU数を取得
# Out:
# 1

# %% [markdown]
# ## 事前学習の実行
# 1. JESCを日本語と英語に分割
# 2. 日本語のトークン化関数 (90)
# 3. 英語のトークン化関数 (90)
# 4. JESCのトークン化
# 5. トークンの保存
# 6. JESCの前処理
# 7. JESCによる事前学習
# 8. JESCのdevデータの翻訳
# 9. JESCのBLEUスコアの確認

# %%
# JESCを日本語文と英語文に分けて保存
def split_ja_en(path):
    with open(path, encoding='utf-8') as f:
        lines = f.readlines()
    
    ja_lines = [line.split('\t')[1] for line in lines]
    en_lines = [line.split('\t')[0]+'\n' for line in lines]

    with open(path + '.ja', 'w') as f:
        f.writelines(''.join(ja_lines))
    with open(path + '.en', 'w') as f:
        f.writelines(''.join(en_lines))

split_ja_en('../data/ch10/JESC_split/train')
split_ja_en('../data/ch10/JESC_split/dev')
split_ja_en('../data/ch10/JESC_split/test')

# %%
# MeCab ipadic NEologdによる形態素分割
import MeCab

wakati = MeCab.Tagger("/usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd -Owakati")

def ja_tokenizer(fname):
    '''
    input :fname
    output:list(token)
    '''
    with open(fname, encoding='utf-8') as f1:
        lines = f1.readlines()
    
    tokens = [wakati.parse(line) for line in lines]

    return tokens

# %%
# mosestokenizerによる単語分割
from mosestokenizer import *

tokenizer = MosesTokenizer('en')

def en_tokenizer(fname):
    '''
    input :fname
    output:list(token)
    '''
    with open(fname, encoding='utf-8') as f2:
        lines = f2.readlines()
    
    tokens = [' '.join(tokenizer(line)) + '\n' for line in lines]

    return tokens

# %%
# ja_tokenizerによるトークン化
train_ja_tokens = ja_tokenizer('../data/ch10/JESC_split/train.ja')
dev_ja_tokens   = ja_tokenizer('../data/ch10/JESC_split/dev.ja')
test_ja_tokens  = ja_tokenizer('../data/ch10/JESC_split/test.ja')

# en_tokenizerによるトークン化
train_en_tokens = en_tokenizer('../data/ch10/JESC_split/train.en')
dev_en_tokens   = en_tokenizer('../data/ch10/JESC_split/dev.en')
test_en_tokens  = en_tokenizer('../data/ch10/JESC_split/test.en')

# %%
# データの保存
def save_token(token, fname):
    with open(fname, 'w') as f:
        f.writelines(token)

save_token(train_ja_tokens, '../data/ch10/98_JESC_train_tokens.ja')
save_token(dev_ja_tokens, '../data/ch10/98_JESC_dev_tokens.ja')
save_token(test_ja_tokens, '../data/ch10/98_JESC_test_tokens.ja')
save_token(train_en_tokens, '../data/ch10/98_JESC_train_tokens.en')
save_token(dev_en_tokens, '../data/ch10/98_JESC_dev_tokens.en')
save_token(test_en_tokens, '../data/ch10/98_JESC_test_tokens.en')

# %%
# JESCの前処理
# !fairseq-preprocess -s ja -t en \
    --trainpref ../data/ch10/98_JESC_train_tokens \
    --validpref ../data/ch10/98_JESC_dev_tokens \
    --destdir ../data/ch10/98_JESC_preprocessed \
    --thresholdsrc 5 \
    --thresholdtgt 5 \
    --workers 20
# Out:
# 2022-08-06 09:06:58 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-06 09:06:58 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='../data/ch10/98_JESC_preprocessed2', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='ja', srcdict=None, suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=5, thresholdtgt=5, tokenizer=None, tpu=False, trainpref='../data/ch10/98_JESC_train_tokens', use_plasma_view=False, user_dir=None, validpref='../data/ch10/98_JESC_dev_tokens', wandb_project=None, workers=20)
# 2022-08-06 09:07:13 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 58088 types
# 2022-08-06 09:07:50 | INFO | fairseq_cli.preprocess | [ja] ../data/ch10/98_JESC_train_tokens.ja: 2797388 sents, 26000267 tokens, 0.62% replaced (by <unk>)
# 2022-08-06 09:07:50 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 58088 types
# 2022-08-06 09:07:51 | INFO | fairseq_cli.preprocess | [ja] ../data/ch10/98_JESC_dev_tokens.ja: 2000 sents, 18520 tokens, 0.74% replaced (by <unk>)
# 2022-08-06 09:07:51 | INFO | fairseq_cli.preprocess | [en] Dictionary: 53968 types
# 2022-08-06 09:08:14 | INFO | fairseq_cli.preprocess | [en] ../data/ch10/98_JESC_train_tokens.en: 2797388 sents, 26693608 tokens, 0.652% replaced (by <unk>)
# 2022-08-06 09:08:14 | INFO | fairseq_cli.preprocess | [en] Dictionary: 53968 types
# 2022-08-06 09:08:15 | INFO | fairseq_cli.preprocess | [en] ../data/ch10/98_JESC_dev_tokens.en: 2000 sents, 18978 tokens, 0.769% replaced (by <unk>)
# 2022-08-06 09:08:15 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to ../data/ch10/98_JESC_preprocessed2

# %%
# JESCによる事前学習
# epoch数を5とする
# !fairseq-train ../data/ch10/98_JESC_preprocessed \
    --save-dir ../data/ch10/98_JESC_pretrained \
    --arch transformer --share-decoder-input-output-embed \
    --encoder-layers 7 --decoder-layers 7 \
    --encoder-embed-dim 512 --decoder-embed-dim 512 \
    --encoder-ffn-embed-dim 1024 --decoder-ffn-embed-dim 1024 \
    --encoder-attention-heads 8 --decoder-attention-heads 8 \
    --encoder-normalize-before --decoder-normalize-before \
    --lr-scheduler inverse_sqrt --warmup-updates 2000 --warmup-init-lr 1e-7 \
    --lr 1e-3 \
    --dropout 0.2 \
    --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --clip-norm 1.0 \
    --max-tokens 8000 \
    --max-epoch 5 \
    --fp16
# Out:
# 2022-08-06 09:08:58 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-06 09:08:59 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 8000, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 8000, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 5, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 1.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.001], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '../data/ch10/98_JESC_pretrained', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoint_on_all_dp_ranks': False, 'wri ...
# 2022-08-06 09:09:00 | INFO | fairseq.tasks.translation | [ja] dictionary: 58088 types
# 2022-08-06 09:09:00 | INFO | fairseq.tasks.translation | [en] dictionary: 53968 types
# 2022-08-06 09:09:01 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(58088, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(53968, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (output_projection): Linear(in_features=512, out_features=53968, bias=False)
#   )
# )
# 2022-08-06 09:09:01 | INFO | fairseq_cli.train | task: TranslationTask
# 2022-08-06 09:09:01 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-08-06 09:09:01 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-08-06 09:09:01 | INFO | fairseq_cli.train | num. shared model params: 108,880,384 (num. trained: 108,880,384)
# 2022-08-06 09:09:01 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-08-06 09:09:01 | INFO | fairseq.data.data_utils | loaded 2,000 examples from: ../data/ch10/98_JESC_preprocessed/valid.ja-en.ja
# 2022-08-06 09:09:01 | INFO | fairseq.data.data_utils | loaded 2,000 examples from: ../data/ch10/98_JESC_preprocessed/valid.ja-en.en
# 2022-08-06 09:09:01 | INFO | fairseq.tasks.translation | ../data/ch10/98_JESC_preprocessed valid ja-en 2000 examples
# 2022-08-06 09:09:02 | INFO | fairseq.trainer | detected shared parameter: decoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-08-06 09:09:02 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-08-06 09:09:02 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 47.544 GB ; name = NVIDIA RTX A6000
# 2022-08-06 09:09:02 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-08-06 09:09:02 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-08-06 09:09:02 | INFO | fairseq_cli.train | max tokens per device = 8000 and max sentences per device = None
# 2022-08-06 09:09:02 | INFO | fairseq.trainer | Preparing to load checkpoint ../data/ch10/98_JESC_pretrained/checkpoint_last.pt
# 2022-08-06 09:09:02 | INFO | fairseq.trainer | No existing checkpoint found ../data/ch10/98_JESC_pretrained/checkpoint_last.pt
# 2022-08-06 09:09:02 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-08-06 09:09:02 | INFO | fairseq.data.data_utils | loaded 2,797,388 examples from: ../data/ch10/98_JESC_preprocessed/train.ja-en.ja
# 2022-08-06 09:09:02 | INFO | fairseq.data.data_utils | loaded 2,797,388 examples from: ../data/ch10/98_JESC_preprocessed/train.ja-en.en
# 2022-08-06 09:09:02 | INFO | fairseq.tasks.translation | ../data/ch10/98_JESC_preprocessed train ja-en 2797388 examples
# 2022-08-06 09:09:03 | INFO | fairseq.data.iterators | grouped total_num_itrs = 3847
# epoch 001:   0%|                                       | 0/3847 [00:00<?, ?it/s]2022-08-06 09:09:03 | INFO | fairseq.trainer | begin training epoch 1
# 2022-08-06 09:09:03 | INFO | fairseq_cli.train | Start iterating over samples
# 2022-08-06 09:09:04 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   0%|                             | 1/3847 [00:01<1:20:54,  1.26s/it]2022-08-06 09:09:04 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001:   0%|                               | 2/3847 [00:01<40:13,  1.59it/s]2022-08-06 09:09:05 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 16.0
# epoch 001:   3%| | 105/3847 [00:13<07:14,  8.61it/s, loss=13.264, nll_loss=12.892022-08-06 09:09:17 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 8.0
# epoch 001: 100%|▉| 3846/3847 [07:24<00:00,  9.09it/s, loss=6.049, nll_loss=4.5772022-08-06 09:16:28 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 001 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  14%|█▏      | 1/7 [00:00<00:00,  6.97it/s]
# epoch 001 | valid on 'valid' subset:  57%|████▌   | 4/7 [00:00<00:00, 18.36it/s]
#                                                                                 2022-08-06 09:16:28 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 5.844 | nll_loss 4.305 | ppl 19.76 | wps 84247.8 | wpb 2711.1 | bsz 285.7 | num_updates 3843
# 2022-08-06 09:16:28 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 3843 updates
# 2022-08-06 09:16:28 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint1.pt
# 2022-08-06 09:16:30 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint1.pt
# 2022-08-06 09:16:31 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_JESC_pretrained/checkpoint1.pt (epoch 1 @ 3843 updates, score 5.844) (writing took 2.80947466311045 seconds)
# 2022-08-06 09:16:31 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-08-06 09:16:31 | INFO | train | epoch 001 | loss 7.014 | nll_loss 5.687 | ppl 51.5 | wps 59745.1 | ups 8.61 | wpb 6937.7 | bsz 726.9 | num_updates 3843 | lr 0.000721406 | gnorm 0.869 | clip 23.1 | loss_scale 8 | train_wall 436 | gb_free 41.1 | wall 449
# 2022-08-06 09:16:31 | INFO | fairseq.data.iterators | grouped total_num_itrs = 3847
# epoch 002:   0%|                                       | 0/3847 [00:00<?, ?it/s]2022-08-06 09:16:31 | INFO | fairseq.trainer | begin training epoch 2
# 2022-08-06 09:16:31 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002: 100%|▉| 3846/3847 [07:24<00:00,  8.76it/s, loss=5.527, nll_loss=3.9882022-08-06 09:23:56 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 002 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  29%|██▎     | 2/7 [00:00<00:00, 16.43it/s]
# epoch 002 | valid on 'valid' subset:  86%|██████▊ | 6/7 [00:00<00:00, 25.26it/s]
#                                                                                 2022-08-06 09:23:56 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 5.474 | nll_loss 3.895 | ppl 14.87 | wps 83908.6 | wpb 2711.1 | bsz 285.7 | num_updates 7690 | best_loss 5.474
# 2022-08-06 09:23:56 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 7690 updates
# 2022-08-06 09:23:56 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint2.pt
# 2022-08-06 09:23:58 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint2.pt
# 2022-08-06 09:24:00 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_JESC_pretrained/checkpoint2.pt (epoch 2 @ 7690 updates, score 5.474) (writing took 4.3652363498695195 seconds)
# 2022-08-06 09:24:00 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-08-06 09:24:00 | INFO | train | epoch 002 | loss 5.706 | nll_loss 4.187 | ppl 18.22 | wps 59389.9 | ups 8.56 | wpb 6938.8 | bsz 727.2 | num_updates 7690 | lr 0.000509978 | gnorm 0.435 | clip 2.4 | loss_scale 8 | train_wall 436 | gb_free 39.4 | wall 898
# 2022-08-06 09:24:01 | INFO | fairseq.data.iterators | grouped total_num_itrs = 3847
# epoch 003:   0%|                                       | 0/3847 [00:00<?, ?it/s]2022-08-06 09:24:01 | INFO | fairseq.trainer | begin training epoch 3
# 2022-08-06 09:24:01 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 003: 100%|▉| 3846/3847 [07:22<00:00,  8.66it/s, loss=5.397, nll_loss=3.8412022-08-06 09:31:23 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 003 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:  29%|██▎     | 2/7 [00:00<00:00, 19.17it/s]
# epoch 003 | valid on 'valid' subset:  71%|█████▋  | 5/7 [00:00<00:00, 25.33it/s]
#                                                                                 2022-08-06 09:31:23 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 5.334 | nll_loss 3.732 | ppl 13.28 | wps 82704.8 | wpb 2711.1 | bsz 285.7 | num_updates 11537 | best_loss 5.334
# 2022-08-06 09:31:23 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 11537 updates
# 2022-08-06 09:31:23 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint3.pt
# 2022-08-06 09:31:25 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint3.pt
# 2022-08-06 09:31:28 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_JESC_pretrained/checkpoint3.pt (epoch 3 @ 11537 updates, score 5.334) (writing took 4.286401443881914 seconds)
# 2022-08-06 09:31:28 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2022-08-06 09:31:28 | INFO | train | epoch 003 | loss 5.401 | nll_loss 3.842 | ppl 14.34 | wps 59701.6 | ups 8.6 | wpb 6938.8 | bsz 727.2 | num_updates 11537 | lr 0.00041636 | gnorm 0.369 | clip 1.4 | loss_scale 8 | train_wall 434 | gb_free 39.3 | wall 1345
# 2022-08-06 09:31:28 | INFO | fairseq.data.iterators | grouped total_num_itrs = 3847
# epoch 004:   0%|                                       | 0/3847 [00:00<?, ?it/s]2022-08-06 09:31:28 | INFO | fairseq.trainer | begin training epoch 4
# 2022-08-06 09:31:28 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 004: 100%|▉| 3846/3847 [07:24<00:00,  9.12it/s, loss=5.256, nll_loss=3.68,2022-08-06 09:38:53 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 004 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  29%|██▎     | 2/7 [00:00<00:00, 18.70it/s]
# epoch 004 | valid on 'valid' subset:  86%|██████▊ | 6/7 [00:00<00:00, 27.19it/s]
#                                                                                 2022-08-06 09:38:53 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 5.242 | nll_loss 3.634 | ppl 12.42 | wps 84301.2 | wpb 2711.1 | bsz 285.7 | num_updates 15384 | best_loss 5.242
# 2022-08-06 09:38:53 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 15384 updates
# 2022-08-06 09:38:53 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint4.pt
# 2022-08-06 09:38:55 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint4.pt
# 2022-08-06 09:38:57 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_JESC_pretrained/checkpoint4.pt (epoch 4 @ 15384 updates, score 5.242) (writing took 4.296168573899195 seconds)
# 2022-08-06 09:38:57 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2022-08-06 09:38:57 | INFO | train | epoch 004 | loss 5.235 | nll_loss 3.654 | ppl 12.58 | wps 59344 | ups 8.55 | wpb 6938.8 | bsz 727.2 | num_updates 15384 | lr 0.000360562 | gnorm 0.346 | clip 1.2 | loss_scale 8 | train_wall 437 | gb_free 40.5 | wall 1795
# 2022-08-06 09:38:58 | INFO | fairseq.data.iterators | grouped total_num_itrs = 3847
# epoch 005:   0%|                                       | 0/3847 [00:00<?, ?it/s]2022-08-06 09:38:58 | INFO | fairseq.trainer | begin training epoch 5
# 2022-08-06 09:38:58 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 005: 100%|▉| 3846/3847 [07:24<00:00,  8.57it/s, loss=5.171, nll_loss=3.5822022-08-06 09:46:22 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 005 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 005 | valid on 'valid' subset:  29%|██▎     | 2/7 [00:00<00:00, 15.83it/s]
# epoch 005 | valid on 'valid' subset:  86%|██████▊ | 6/7 [00:00<00:00, 25.36it/s]
#                                                                                 2022-08-06 09:46:22 | INFO | valid | epoch 005 | valid on 'valid' subset | loss 5.19 | nll_loss 3.574 | ppl 11.91 | wps 86678.6 | wpb 2711.1 | bsz 285.7 | num_updates 19231 | best_loss 5.19
# 2022-08-06 09:46:22 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 5 @ 19231 updates
# 2022-08-06 09:46:22 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint5.pt
# 2022-08-06 09:46:24 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_JESC_pretrained/checkpoint5.pt
# 2022-08-06 09:46:26 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_JESC_pretrained/checkpoint5.pt (epoch 5 @ 19231 updates, score 5.19) (writing took 4.290687626926228 seconds)
# 2022-08-06 09:46:26 | INFO | fairseq_cli.train | end of epoch 5 (average epoch stats below)
# 2022-08-06 09:46:26 | INFO | train | epoch 005 | loss 5.123 | nll_loss 3.526 | ppl 11.52 | wps 59442.6 | ups 8.57 | wpb 6938.8 | bsz 727.2 | num_updates 19231 | lr 0.000322488 | gnorm 0.337 | clip 1.1 | loss_scale 16 | train_wall 436 | gb_free 39.7 | wall 2244
# 2022-08-06 09:46:27 | INFO | fairseq_cli.train | done training in 2243.6 seconds

# %%
# devデータの翻訳
# !fairseq-interactive --path ../data/ch10/98_JESC_pretrained/checkpoint_best.pt ../data/ch10/98_JESC_preprocessed < ../data/ch10/98_JESC_dev_tokens.ja | grep '^H' | cut -f3 > ../data/ch10/98_JESC_dev_transformed.en
# Out:
# 2022-08-06 09:46:39 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-06 09:46:40 | INFO | fairseq_cli.interactive | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': '../data/ch10/98_JESC_pretrained/checkpoint_best.pt', 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 1, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoi ...
# 2022-08-06 09:46:40 | INFO | fairseq.tasks.translation | [ja] dictionary: 58088 types
# 2022-08-06 09:46:40 | INFO | fairseq.tasks.translation | [en] dictionary: 53968 types
# 2022-08-06 09:46:40 | INFO | fairseq_cli.interactive | loading model(s) from ../data/ch10/98_JESC_pretrained/checkpoint_best.pt
# 2022-08-06 09:46:46 | INFO | fairseq_cli.interactive | NOTE: hypothesis and token scores are output in base 2
# 2022-08-06 09:46:46 | INFO | fairseq_cli.interactive | Type the input sentence and press return:
# 2022-08-06 09:49:35 | INFO | fairseq_cli.interactive | Total time: 174.957 seconds; translation time: 163.775

# %%
# BLEUスコアの計測
# !fairseq-score --sys ../data/ch10/98_JESC_dev_transformed.en --ref ../data/ch10/98_JESC_dev_tokens.en
# Out:
# 2022-08-06 09:49:37 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# Namespace(ignore_case=False, order=4, ref='../data/ch10/98_JESC_dev_tokens.en', sacrebleu=False, sentence_bleu=False, sys='../data/ch10/98_JESC_dev_transformed.en')
# BLEU4 = 15.41, 43.1/19.9/11.4/6.6 (BP=0.967, ratio=0.967, syslen=16424, reflen=16978)

# %% [markdown]
# ## ファインチューニングの実行
# 1. 事前学習に合わせたデータの前処理
# 2. KFTTでファインチューニング
# 3. devデータの翻訳
# 4. BLEUスコアの計測

# %%
# KFTTの前処理
# !fairseq-preprocess -s ja -t en \
    --trainpref ../data/ch10/90_train_tokens \
    --validpref ../data/ch10/90_dev_tokens \
    --srcdict ../data/ch10/98_JESC_preprocessed/dict.ja.txt \
    --tgtdict ../data/ch10/98_JESC_preprocessed/dict.en.txt \
    --destdir ../data/ch10/98_preprocessed \
    --workers 20
# Out:
# 2022-08-06 10:03:50 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-06 10:03:50 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='../data/ch10/98_preprocessed', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='ja', srcdict='../data/ch10/98_JESC_preprocessed/dict.ja.txt', suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict='../data/ch10/98_JESC_preprocessed/dict.en.txt', threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, tpu=False, trainpref='../data/ch10/90_train_tokens', use_plasma_view=False, user_dir=None, validpref='../data/ch10/90_dev_tokens', wandb_project=None, workers=20)
# 2022-08-06 10:03:51 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 58088 types
# 2022-08-06 10:04:01 | INFO | fairseq_cli.preprocess | [ja] ../data/ch10/90_train_tokens.ja: 440288 sents, 11384681 tokens, 12.0% replaced (by <unk>)
# 2022-08-06 10:04:01 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 58088 types
# 2022-08-06 10:04:02 | INFO | fairseq_cli.preprocess | [ja] ../data/ch10/90_dev_tokens.ja: 1166 sents, 25978 tokens, 14.1% replaced (by <unk>)
# 2022-08-06 10:04:02 | INFO | fairseq_cli.preprocess | [en] Dictionary: 53968 types
# 2022-08-06 10:04:10 | INFO | fairseq_cli.preprocess | [en] ../data/ch10/90_train_tokens.en: 440288 sents, 12318431 tokens, 23.1% replaced (by <unk>)
# 2022-08-06 10:04:10 | INFO | fairseq_cli.preprocess | [en] Dictionary: 53968 types
# 2022-08-06 10:04:10 | INFO | fairseq_cli.preprocess | [en] ../data/ch10/90_dev_tokens.en: 1166 sents, 26265 tokens, 29.2% replaced (by <unk>)
# 2022-08-06 10:04:10 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to ../data/ch10/98_preprocessed

# %%
# KFTTによるファインチューニング
# !fairseq-train ../data/ch10/98_preprocessed \
    --restore-file ../data/ch10/98_JESC_pretrained/checkpoint_best.pt \
    --save-dir ../data/ch10/98_trained \
    --arch transformer --share-decoder-input-output-embed \
    --encoder-layers 7 --decoder-layers 7 \
    --encoder-embed-dim 512 --decoder-embed-dim 512 \
    --encoder-ffn-embed-dim 1024 --decoder-ffn-embed-dim 1024 \
    --encoder-attention-heads 8 --decoder-attention-heads 8 \
    --encoder-normalize-before --decoder-normalize-before \
    --lr-scheduler inverse_sqrt --warmup-updates 2000 --warmup-init-lr 1e-7 \
    --lr 1e-3 \
    --dropout 0.2 \
    --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --clip-norm 1.0 \
    --max-tokens 8000 \
    --max-epoch 20 \
    --fp16
# Out:
# 2022-08-06 10:04:18 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-06 10:04:20 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 8000, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 8000, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 20, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 1.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.001], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '../data/ch10/98_trained', 'restore_file': '../data/ch10/98_JESC_pretrained/checkpoint_best.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoint_on_a ...
# 2022-08-06 10:04:20 | INFO | fairseq.tasks.translation | [ja] dictionary: 58088 types
# 2022-08-06 10:04:20 | INFO | fairseq.tasks.translation | [en] dictionary: 53968 types
# 2022-08-06 10:04:22 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(58088, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(53968, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (output_projection): Linear(in_features=512, out_features=53968, bias=False)
#   )
# )
# 2022-08-06 10:04:22 | INFO | fairseq_cli.train | task: TranslationTask
# 2022-08-06 10:04:22 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-08-06 10:04:22 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-08-06 10:04:22 | INFO | fairseq_cli.train | num. shared model params: 108,880,384 (num. trained: 108,880,384)
# 2022-08-06 10:04:22 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-08-06 10:04:22 | INFO | fairseq.data.data_utils | loaded 1,166 examples from: ../data/ch10/98_preprocessed/valid.ja-en.ja
# 2022-08-06 10:04:22 | INFO | fairseq.data.data_utils | loaded 1,166 examples from: ../data/ch10/98_preprocessed/valid.ja-en.en
# 2022-08-06 10:04:22 | INFO | fairseq.tasks.translation | ../data/ch10/98_preprocessed valid ja-en 1166 examples
# 2022-08-06 10:04:23 | INFO | fairseq.trainer | detected shared parameter: decoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-08-06 10:04:23 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-08-06 10:04:23 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 47.544 GB ; name = NVIDIA RTX A6000
# 2022-08-06 10:04:23 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-08-06 10:04:23 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-08-06 10:04:23 | INFO | fairseq_cli.train | max tokens per device = 8000 and max sentences per device = None
# 2022-08-06 10:04:23 | INFO | fairseq.trainer | Preparing to load checkpoint ../data/ch10/98_JESC_pretrained/checkpoint_best.pt
# 2022-08-06 10:04:24 | INFO | fairseq.trainer | Loaded checkpoint ../data/ch10/98_JESC_pretrained/checkpoint_best.pt (epoch 6 @ 19231 updates)
# 2022-08-06 10:04:24 | INFO | fairseq.trainer | loading train data for epoch 6
# 2022-08-06 10:04:24 | INFO | fairseq.data.data_utils | loaded 440,288 examples from: ../data/ch10/98_preprocessed/train.ja-en.ja
# 2022-08-06 10:04:24 | INFO | fairseq.data.data_utils | loaded 440,288 examples from: ../data/ch10/98_preprocessed/train.ja-en.en
# 2022-08-06 10:04:24 | INFO | fairseq.tasks.translation | ../data/ch10/98_preprocessed train ja-en 440288 examples
# 2022-08-06 10:04:24 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 006:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-06 10:04:24 | INFO | fairseq.trainer | begin training epoch 6
# 2022-08-06 10:04:24 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 006:   0%|                               | 2/1809 [00:01<17:42,  1.70it/s]2022-08-06 10:04:26 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 8.0
# epoch 006: 100%|▉| 1808/1809 [03:33<00:00,  8.71it/s, loss=5.079, nll_loss=3.4892022-08-06 10:07:58 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 006 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 006 | valid on 'valid' subset:  12%|█       | 1/8 [00:00<00:00,  7.47it/s]
# epoch 006 | valid on 'valid' subset:  62%|█████   | 5/8 [00:00<00:00, 21.13it/s]
#                                                                                 2022-08-06 10:07:59 | INFO | valid | epoch 006 | valid on 'valid' subset | loss 4.812 | nll_loss 3.166 | ppl 8.98 | wps 112186 | wpb 3283.1 | bsz 145.8 | num_updates 21039 | best_loss 4.812
# 2022-08-06 10:07:59 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch
| INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_trained/checkpoint17.pt (epoch 17 @ 40937 updates, score 4.427) (writing took 4.986491693882272 seconds)
# 2022-08-06 10:47:34 | INFO | fairseq_cli.train | end of epoch 17 (average epoch stats below)
# 2022-08-06 10:47:34 | INFO | train | epoch 017 | loss 4.071 | nll_loss 2.357 | ppl 5.12 | wps 57149.9 | ups 8.39 | wpb 6809.5 | bsz 243.4 | num_updates 40937 | lr 0.000221033 | gnorm 0.379 | clip 0.7 | loss_scale 8 | train_wall 206 | gb_free 39.4 | wall 2591
# 2022-08-06 10:47:34 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 018:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-06 10:47:34 | INFO | fairseq.trainer | begin training epoch 18
# 2022-08-06 10:47:34 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 018: 100%|▉| 1807/1809 [03:30<00:00,  8.43it/s, loss=4.049, nll_loss=2.3322022-08-06 10:51:05 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 018 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 018 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 19.21it/s]
# epoch 018 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 26.16it/s]
#                                                                                 2022-08-06 10:51:05 | INFO | valid | epoch 018 | valid on 'valid' subset | loss 4.424 | nll_loss 2.725 | ppl 6.61 | wps 109895 | wpb 3283.1 | bsz 145.8 | num_updates 42746 | best_loss 4.417
# 2022-08-06 10:51:05 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 18 @ 42746 updates
# 2022-08-06 10:51:05 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_trained/checkpoint18.pt
# 2022-08-06 10:51:07 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_trained/checkpoint18.pt
# 2022-08-06 10:51:12 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_trained/checkpoint18.pt (epoch 18 @ 42746 updates, score 4.424) (writing took 7.433339322917163 seconds)
# 2022-08-06 10:51:12 | INFO | fairseq_cli.train | end of epoch 18 (average epoch stats below)
# 2022-08-06 10:51:12 | INFO | train | epoch 018 | loss 4.036 | nll_loss 2.316 | ppl 4.98 | wps 56412.6 | ups 8.28 | wpb 6809.5 | bsz 243.4 | num_updates 42746 | lr 0.000216305 | gnorm 0.382 | clip 0.7 | loss_scale 8 | train_wall 206 | gb_free 39.5 | wall 2809
# 2022-08-06 10:51:13 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 019:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-06 10:51:13 | INFO | fairseq.trainer | begin training epoch 19
# 2022-08-06 10:51:13 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 019: 100%|▉| 1808/1809 [03:30<00:00,  8.67it/s, loss=3.989, nll_loss=2.2642022-08-06 10:54:43 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 019 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 019 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 17.69it/s]
# epoch 019 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 25.88it/s]
#                                                                                 2022-08-06 10:54:44 | INFO | valid | epoch 019 | valid on 'valid' subset | loss 4.425 | nll_loss 2.723 | ppl 6.6 | wps 112477 | wpb 3283.1 | bsz 145.8 | num_updates 44555 | best_loss 4.417
# 2022-08-06 10:54:44 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 19 @ 44555 updates
# 2022-08-06 10:54:44 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_trained/checkpoint19.pt
# 2022-08-06 10:54:45 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_trained/checkpoint19.pt
# 2022-08-06 10:54:49 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_trained/checkpoint19.pt (epoch 19 @ 44555 updates, score 4.425) (writing took 5.633307938929647 seconds)
# 2022-08-06 10:54:49 | INFO | fairseq_cli.train | end of epoch 19 (average epoch stats below)
# 2022-08-06 10:54:49 | INFO | train | epoch 019 | loss 4.002 | nll_loss 2.278 | ppl 4.85 | wps 56812 | ups 8.34 | wpb 6809.5 | bsz 243.4 | num_updates 44555 | lr 0.000211869 | gnorm 0.383 | clip 0.6 | loss_scale 8 | train_wall 207 | gb_free 40.1 | wall 3026
# 2022-08-06 10:54:49 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 020:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-06 10:54:49 | INFO | fairseq.trainer | begin training epoch 20
# 2022-08-06 10:54:49 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 020: 100%|▉| 1808/1809 [03:30<00:00,  8.83it/s, loss=4.009, nll_loss=2.2852022-08-06 10:58:20 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 020 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 020 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 18.78it/s]
# epoch 020 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 25.79it/s]
#                                                                                 2022-08-06 10:58:20 | INFO | valid | epoch 020 | valid on 'valid' subset | loss 4.433 | nll_loss 2.733 | ppl 6.65 | wps 110820 | wpb 3283.1 | bsz 145.8 | num_updates 46364 | best_loss 4.417
# 2022-08-06 10:58:20 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 20 @ 46364 updates
# 2022-08-06 10:58:20 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/98_trained/checkpoint20.pt
# 2022-08-06 10:58:22 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/98_trained/checkpoint20.pt
# 2022-08-06 10:58:25 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/98_trained/checkpoint20.pt (epoch 20 @ 46364 updates, score 4.433) (writing took 5.043014533817768 seconds)
# 2022-08-06 10:58:25 | INFO | fairseq_cli.train | end of epoch 20 (average epoch stats below)
# 2022-08-06 10:58:25 | INFO | train | epoch 020 | loss 3.972 | nll_loss 2.243 | ppl 4.73 | wps 57036.5 | ups 8.38 | wpb 6809.5 | bsz 243.4 | num_updates 46364 | lr 0.000207694 | gnorm 0.385 | clip 0.7 | loss_scale 8 | train_wall 206 | gb_free 39.7 | wall 3242
# 2022-08-06 10:58:25 | INFO | fairseq_cli.train | done training in 3240.9 seconds

# %%
# devデータの翻訳
# !fairseq-interactive --path ../data/ch10/98_trained/checkpoint_best.pt ../data/ch10/98_preprocessed < ../data/ch10/90_dev_tokens.ja | grep '^H' | cut -f3 > ../data/ch10/98_dev_transformed.en
# Out:
# 2022-08-06 11:00:08 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-06 11:00:09 | INFO | fairseq_cli.interactive | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': '../data/ch10/98_trained/checkpoint_best.pt', 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 1, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoint_on_al ...
# 2022-08-06 11:00:10 | INFO | fairseq.tasks.translation | [ja] dictionary: 58088 types
# 2022-08-06 11:00:10 | INFO | fairseq.tasks.translation | [en] dictionary: 53968 types
# 2022-08-06 11:00:10 | INFO | fairseq_cli.interactive | loading model(s) from ../data/ch10/98_trained/checkpoint_best.pt
# 2022-08-06 11:00:13 | INFO | fairseq_cli.interactive | NOTE: hypothesis and token scores are output in base 2
# 2022-08-06 11:00:13 | INFO | fairseq_cli.interactive | Type the input sentence and press return:
# 2022-08-06 11:04:03 | INFO | fairseq_cli.interactive | Total time: 233.859 seconds; translation time: 225.419

# %%
# BLEUスコアの計測
# !fairseq-score --sys ../data/ch10/98_dev_transformed.en --ref ../data/ch10/90_dev_tokens.en
# Out:
# 2022-08-06 11:04:46 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# Namespace(ignore_case=False, order=4, ref='../data/ch10/90_dev_tokens.en', sacrebleu=False, sentence_bleu=False, sys='../data/ch10/98_dev_transformed.en')
# BLEU4 = 7.38, 33.1/10.5/4.3/2.0 (BP=1.000, ratio=1.062, syslen=26647, reflen=25099)
