# %% [markdown]
# # 91. 機械翻訳モデルの訓練
# 90で準備したデータを用いて，ニューラル機械翻訳のモデルを学習せよ（ニューラルネットワークのモデルはTransformerやLSTMなど適当に選んでよい）．

# %% [markdown]
# ## GPU prepare
# 1. 使用可能GPUの確認
# 2. GPUの指定
# 3. PyTorchで利用できるGPU数の確認

# %%
# 使用可能GPUの確認
# !nvidia-smi
# Out:
# Fri Aug  5 14:17:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A6000    On   | 00000000:01:00.0 Off |                  Off |
# | 30%   31C    P8    24W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A6000    On   | 00000000:25:00.0 Off |                  Off |
# | 43%   71C    P2   271W / 300W |  26097MiB / 48685MiB |     92%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A6000    On   | 00000000:41:00.0 Off |                  Off |
# | 30%   28C    P8    29W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A6000    On   | 00000000:61:00.0 Off |                  Off |
# | 30%   27C    P8    19W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A6000    On   | 00000000:81:00.0 Off |                  Off |
# | 30%   28C    P8    18W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A6000    On   | 00000000:A1:00.0 Off |                  Off |
# | 30%   26C    P8    18W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A6000    On   | 00000000:C1:00.0 Off |                  Off |
# | 30%   28C    P8    16W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A6000    On   | 00000000:E1:00.0 Off |                  Off |
# | 30%   27C    P8    14W / 300W |      8MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# GPUの指定
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1' #0番を使用するとき

# %%
# 確認
import torch
print(torch.cuda.device_count()) #Pytorchで使用できるGPU数を取得
# Out:
# 1

# %% [markdown]
# ## 翻訳モデルの訓練
# 1. データの前処理
# 2. モデルの訓練

# %%
# 前処理
# !fairseq-preprocess -s ja -t en \
    --trainpref ../data/ch10/90_train_tokens \
    --validpref ../data/ch10/90_dev_tokens \
    --destdir ../data/ch10/91_preprocessed \
    --thresholdsrc 5 \
    --thresholdtgt 5 \
    --workers 20
# Out:
# 2022-08-05 03:23:05 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-05 03:23:05 | INFO | fairseq_cli.preprocess | Namespace(aim_repo=None, aim_run_hash=None, align_suffix=None, alignfile=None, all_gather_list_size=16384, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, azureml_logging=False, bf16=False, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='../data/ch10/91_preprocessed', dict_only=False, empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_file=None, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, on_cpu_convert_precision=False, only_source=False, optimizer=None, padding_factor=8, plasma_path='/tmp/plasma', profile=False, quantization_config_path=None, reset_logging=False, scoring='bleu', seed=1, source_lang='ja', srcdict=None, suppress_crashes=False, target_lang='en', task='translation', tensorboard_logdir=None, testpref=None, tgtdict=None, threshold_loss_scale=None, thresholdsrc=5, thresholdtgt=5, tokenizer=None, tpu=False, trainpref='../data/ch10/90_train_tokens', use_plasma_view=False, user_dir=None, validpref='../data/ch10/90_dev_tokens', wandb_project=None, workers=20)
# 2022-08-05 03:23:11 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 49320 types
# 2022-08-05 03:23:21 | INFO | fairseq_cli.preprocess | [ja] ../data/ch10/90_train_tokens.ja: 440288 sents, 11384681 tokens, 1.01% replaced (by <unk>)
# 2022-08-05 03:23:21 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 49320 types
# 2022-08-05 03:23:22 | INFO | fairseq_cli.preprocess | [ja] ../data/ch10/90_dev_tokens.ja: 1166 sents, 25978 tokens, 1.04% replaced (by <unk>)
# 2022-08-05 03:23:22 | INFO | fairseq_cli.preprocess | [en] Dictionary: 55728 types
# 2022-08-05 03:23:30 | INFO | fairseq_cli.preprocess | [en] ../data/ch10/90_train_tokens.en: 440288 sents, 12318431 tokens, 1.61% replaced (by <unk>)
# 2022-08-05 03:23:30 | INFO | fairseq_cli.preprocess | [en] Dictionary: 55728 types
# 2022-08-05 03:23:31 | INFO | fairseq_cli.preprocess | [en] ../data/ch10/90_dev_tokens.en: 1166 sents, 26265 tokens, 2.64% replaced (by <unk>)
# 2022-08-05 03:23:31 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to ../data/ch10/91_preprocessed

# %%
# モデルの訓練
# !fairseq-train ../data/ch10/91_preprocessed \
    --save-dir ../data/ch10/91_trained \
    --arch transformer --share-decoder-input-output-embed \
    --lr-scheduler inverse_sqrt --warmup-updates 2000 --warmup-init-lr 1e-7 \
    --lr 1e-3 \
    --dropout 0.2 \
    --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --clip-norm 1.0 \
    --max-tokens 8000 \
    --max-epoch 20 \
    --fp16
# Out:
# 2022-08-05 14:17:58 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2022-08-05 14:18:00 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 8000, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 8000, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 20, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 1.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.001], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': '../data/ch10/91_trained', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoint_on_all_dp_ranks': False, 'write_chec ...
# 2022-08-05 14:18:00 | INFO | fairseq.tasks.translation | [ja] dictionary: 49320 types
# 2022-08-05 14:18:00 | INFO | fairseq.tasks.translation | [en] dictionary: 55728 types
# 2022-08-05 14:18:01 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(49320, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(55728, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=512, out_features=55728, bias=False)
#   )
# )
# 2022-08-05 14:18:01 | INFO | fairseq_cli.train | task: TranslationTask
# 2022-08-05 14:18:01 | INFO | fairseq_cli.train | model: TransformerModel
# 2022-08-05 14:18:01 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2022-08-05 14:18:01 | INFO | fairseq_cli.train | num. shared model params: 116,825,088 (num. trained: 116,825,088)
# 2022-08-05 14:18:01 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2022-08-05 14:18:01 | INFO | fairseq.data.data_utils | loaded 1,166 examples from: ../data/ch10/91_preprocessed/valid.ja-en.ja
# 2022-08-05 14:18:01 | INFO | fairseq.data.data_utils | loaded 1,166 examples from: ../data/ch10/91_preprocessed/valid.ja-en.en
# 2022-08-05 14:18:01 | INFO | fairseq.tasks.translation | ../data/ch10/91_preprocessed valid ja-en 1166 examples
# 2022-08-05 14:18:03 | INFO | fairseq.trainer | detected shared parameter: decoder.embed_tokens.weight <- decoder.output_projection.weight
# 2022-08-05 14:18:03 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-08-05 14:18:03 | INFO | fairseq.utils | rank   0: capabilities =  8.6  ; total memory = 47.544 GB ; name = NVIDIA RTX A6000
# 2022-08-05 14:18:03 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2022-08-05 14:18:03 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-08-05 14:18:03 | INFO | fairseq_cli.train | max tokens per device = 8000 and max sentences per device = None
# 2022-08-05 14:18:03 | INFO | fairseq.trainer | Preparing to load checkpoint ../data/ch10/91_trained/checkpoint_last.pt
# 2022-08-05 14:18:03 | INFO | fairseq.trainer | No existing checkpoint found ../data/ch10/91_trained/checkpoint_last.pt
# 2022-08-05 14:18:03 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-08-05 14:18:03 | INFO | fairseq.data.data_utils | loaded 440,288 examples from: ../data/ch10/91_preprocessed/train.ja-en.ja
# 2022-08-05 14:18:03 | INFO | fairseq.data.data_utils | loaded 440,288 examples from: ../data/ch10/91_preprocessed/train.ja-en.en
# 2022-08-05 14:18:03 | INFO | fairseq.tasks.translation | ../data/ch10/91_preprocessed train ja-en 440288 examples
# 2022-08-05 14:18:03 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 001:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 14:18:03 | INFO | fairseq.trainer | begin training epoch 1
# 2022-08-05 14:18:03 | INFO | fairseq_cli.train | Start iterating over samples
# 2022-08-05 14:18:05 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 64.0
# epoch 001:   0%|                               | 2/1809 [00:02<28:44,  1.05it/s]2022-08-05 14:18:06 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 32.0
# epoch 001:   3%|▉                             | 60/1809 [00:16<07:15,  4.02it/s]2022-08-05 14:18:20 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 16.0
# epoch 001:  44%|▍| 800/1809 [03:14<04:03,  4.14it/s, loss=8.79, nll_loss=7.716, 2022-08-05 14:21:18 | INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 8.0
# epoch 001: 100%|▉| 1808/1809 [05:25<00:00,  8.68it/s, loss=7.535, nll_loss=6.2412022-08-05 14:23:29 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 001 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  12%|█       | 1/8 [00:00<00:01,  6.58it/s]
# epoch 001 | valid on 'valid' subset:  62%|█████   | 5/8 [00:00<00:00, 20.37it/s]
#                                                                                 2022-08-05 14:23:29 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 7.649 | nll_loss 6.313 | ppl 79.48 | wps 116909 | wpb 3283.1 | bsz 145.8 | num_updates 1805
# 2022-08-05 14:23:29 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 1805 updates
# 2022-08-05 14:23:29 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint1.pt
# 2022-08-05 14:23:31 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint1.pt
# 2022-08-05 14:23:34 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint1.pt (epoch 1 @ 1805 updates, score 7.649) (writing took 4.763723285868764 seconds)
# 2022-08-05 14:23:34 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-08-05 14:23:34 | INFO | train | epoch 001 | loss 8.803 | nll_loss 7.724 | ppl 211.36 | wps 37407.4 | ups 5.49 | wpb 6807.5 | bsz 241 | num_updates 1805 | lr 0.00090251 | gnorm 1.389 | clip 60.7 | loss_scale 8 | train_wall 322 | gb_free 39 | wall 331
# 2022-08-05 14:23:34 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 002:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 14:23:34 | INFO | fairseq.trainer | begin training epoch 2
# 2022-08-05 14:23:34 | INFO | fairseq_cli.train | Start iterating over samples
# epoch
| INFO | fairseq.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 2.0
# epoch 004: 100%|▉| 1808/1809 [03:24<00:00,  9.06it/s, loss=5.981, nll_loss=4.4522022-08-05 14:34:02 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 004 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 22.99it/s]
# epoch 004 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.51it/s]
#                                                                                 2022-08-05 14:34:02 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 6.724 | nll_loss 5.235 | ppl 37.65 | wps 114083 | wpb 3283.1 | bsz 145.8 | num_updates 7230 | best_loss 6.724
# 2022-08-05 14:34:02 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 7230 updates
# 2022-08-05 14:34:02 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint4.pt
# 2022-08-05 14:34:04 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint4.pt
# 2022-08-05 14:34:07 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint4.pt (epoch 4 @ 7230 updates, score 6.724) (writing took 4.945617306046188 seconds)
# 2022-08-05 14:34:07 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2022-08-05 14:34:07 | INFO | train | epoch 004 | loss 6.104 | nll_loss 4.591 | ppl 24.1 | wps 58489.2 | ups 8.59 | wpb 6808.9 | bsz 241.3 | num_updates 7230 | lr 0.000525952 | gnorm 0.589 | clip 3.5 | loss_scale 2 | train_wall 201 | gb_free 39.1 | wall 964
# 2022-08-05 14:34:07 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 005:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 14:34:07 | INFO | fairseq.trainer | begin training epoch 5
# 2022-08-05 14:34:07 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 005: 100%|▉| 1808/1809 [03:24<00:00,  8.95it/s, loss=5.831, nll_loss=4.2762022-08-05 14:37:32 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 005 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 005 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 24.22it/s]
# epoch 005 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 30.06it/s]
#                                                                                 2022-08-05 14:37:32 | INFO | valid | epoch 005 | valid on 'valid' subset | loss 6.629 | nll_loss 5.119 | ppl 34.75 | wps 116250 | wpb 3283.1 | bsz 145.8 | num_updates 9039 | best_loss 6.629
# 2022-08-05 14:37:32 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 5 @ 9039 updates
# 2022-08-05 14:37:32 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint5.pt
# 2022-08-05 14:37:34 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint5.pt
# 2022-08-05 14:37:37 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint5.pt (epoch 5 @ 9039 updates, score 6.629) (writing took 4.736178748076782 seconds)
# 2022-08-05 14:37:37 | INFO | fairseq_cli.train | end of epoch 5 (average epoch stats below)
# 2022-08-05 14:37:37 | INFO | train | epoch 005 | loss 5.89 | nll_loss 4.342 | ppl 20.28 | wps 58682.9 | ups 8.62 | wpb 6809.5 | bsz 243.4 | num_updates 9039 | lr 0.000470386 | gnorm 0.597 | clip 3.6 | loss_scale 2 | train_wall 201 | gb_free 39.1 | wall 1174
# 2022-08-05 14:37:37 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 006:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 14:37:37 | INFO | fairseq.trainer | begin training epoch 6
# 2022-08-05 14:37:37 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 006: 100%|▉| 1808/1809 [03:25<00:00,  9.05it/s, loss=5.658, nll_loss=4.0752022-08-05 14:41:03 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch
| INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 013:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:02:08 | INFO | fairseq.trainer | begin training epoch 13
# 2022-08-05 15:02:08 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 013: 100%|▉| 1808/1809 [03:24<00:00,  8.85it/s, loss=5.113, nll_loss=3.4382022-08-05 15:05:32 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 013 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 013 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 23.10it/s]
# epoch 013 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.64it/s]
#                                                                                 2022-08-05 15:05:32 | INFO | valid | epoch 013 | valid on 'valid' subset | loss 6.565 | nll_loss 5.015 | ppl 32.34 | wps 112618 | wpb 3283.1 | bsz 145.8 | num_updates 23511 | best_loss 6.42
# 2022-08-05 15:05:32 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 13 @ 23511 updates
# 2022-08-05 15:05:32 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint13.pt
# 2022-08-05 15:05:34 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint13.pt
# 2022-08-05 15:05:36 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint13.pt (epoch 13 @ 23511 updates, score 6.565) (writing took 3.263965295162052 seconds)
# 2022-08-05 15:05:36 | INFO | fairseq_cli.train | end of epoch 13 (average epoch stats below)
# 2022-08-05 15:05:36 | INFO | train | epoch 013 | loss 5.111 | nll_loss 3.432 | ppl 10.8 | wps 59251.5 | ups 8.7 | wpb 6809.5 | bsz 243.4 | num_updates 23511 | lr 0.000291662 | gnorm 0.657 | clip 4.1 | loss_scale 4 | train_wall 201 | gb_free 39.4 | wall 2853
# 2022-08-05 15:05:36 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 014:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:05:36 | INFO | fairseq.trainer | begin training epoch 14
# 2022-08-05 15:05:36 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 014: 100%|▉| 1808/1809 [03:23<00:00,  8.98it/s, loss=5.049, nll_loss=3.3612022-08-05 15:08:59 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 014 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 014 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 22.95it/s]
# epoch 014 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.50it/s]
#                                                                                 2022-08-05 15:09:00 | INFO | valid | epoch 014 | valid on 'valid' subset | loss 6.582 | nll_loss 5.042 | ppl 32.94 | wps 113609 | wpb 3283.1 | bsz 145.8 | num_updates 25320 | best_loss 6.42
# 2022-08-05 15:09:00 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 14 @ 25320 updates
# 2022-08-05 15:09:00 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint14.pt
# 2022-08-05 15:09:02 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint14.pt
# 2022-08-05 15:09:03 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint14.pt (epoch 14 @ 25320 updates, score 6.582) (writing took 3.2811086028814316 seconds)
# 2022-08-05 15:09:03 | INFO | fairseq_cli.train | end of epoch 14 (average epoch stats below)
# 2022-08-05 15:09:03 | INFO | train | epoch 014 | loss 5.058 | nll_loss 3.37 | ppl 10.34 | wps 59377.1 | ups 8.72 | wpb 6809.5 | bsz 243.4 | num_updates 25320 | lr 0.00028105 | gnorm 0.666 | clip 4.3 | loss_scale 4 | train_wall 200 | gb_free 39.3 | wall 3060
# 2022-08-05 15:09:03 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 015:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:09:03 | INFO | fairseq.trainer | begin training epoch 15
# 2022-08-05 15:09:03 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 015: 100%|▉| 1808/1809 [03:25<00:00,  9.04it/s, loss=5.023, nll_loss=3.3292022-08-05 15:12:29 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 015 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 015 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 18.76it/s]
# epoch 015 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 26.39it/s]
#                                                                                 2022-08-05 15:12:29 | INFO | valid | epoch 015 | valid on 'valid' subset | loss 6.571 | nll_loss 5.023 | ppl 32.52 | wps 115158 | wpb 3283.1 | bsz 145.8 | num_updates 27129 | best_loss 6.42
# 2022-08-05 15:12:29 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 15 @ 27129 updates
# 2022-08-05 15:12:29 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint15.pt
# 2022-08-05 15:12:31 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint15.pt
# 2022-08-05 15:12:32 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint15.pt (epoch 15 @ 27129 updates, score 6.571) (writing took 3.2601905479095876 seconds)
# 2022-08-05 15:12:32 | INFO | fairseq_cli.train | end of epoch 15 (average epoch stats below)
# 2022-08-05 15:12:32 | INFO | train | epoch 015 | loss 5.01 | nll_loss 3.313 | ppl 9.94 | wps 58851.7 | ups 8.64 | wpb 6809.5 | bsz 243.4 | num_updates 27129 | lr 0.000271518 | gnorm 0.677 | clip 4.9 | loss_scale 4 | train_wall 202 | gb_free 39.1 | wall 3269
# 2022-08-05 15:12:33 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 016:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:12:33 | INFO | fairseq.trainer | begin training epoch 16
# 2022-08-05 15:12:33 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 016: 100%|▉| 1808/1809 [03:24<00:00,  8.92it/s, loss=5.047, nll_loss=3.3572022-08-05 15:15:57 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 016 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 016 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 23.10it/s]
# epoch 016 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.57it/s]
#                                                                                 2022-08-05 15:15:58 | INFO | valid | epoch 016 | valid on 'valid' subset | loss 6.644 | nll_loss 5.106 | ppl 34.43 | wps 114212 | wpb 3283.1 | bsz 145.8 | num_updates 28938 | best_loss 6.42
# 2022-08-05 15:15:58 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 16 @ 28938 updates
# 2022-08-05 15:15:58 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint16.pt
# 2022-08-05 15:16:00 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint16.pt
# 2022-08-05 15:16:01 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint16.pt (epoch 16 @ 28938 updates, score 6.644) (writing took 3.242588704219088 seconds)
# 2022-08-05 15:16:01 | INFO | fairseq_cli.train | end of epoch 16 (average epoch stats below)
# 2022-08-05 15:16:01 | INFO | train | epoch 016 | loss 4.965 | nll_loss 3.26 | ppl 9.58 | wps 59014.3 | ups 8.67 | wpb 6809.5 | bsz 243.4 | num_updates 28938 | lr 0.000262894 | gnorm 0.685 | clip 4.8 | loss_scale 4 | train_wall 201 | gb_free 40.9 | wall 3478
# 2022-08-05 15:16:01 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 017:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:16:01 | INFO | fairseq.trainer | begin training epoch 17
# 2022-08-05 15:16:01 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 017: 100%|▉| 1808/1809 [03:26<00:00,  8.76it/s, loss=4.979, nll_loss=3.2762022-08-05 15:19:28 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 017 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 017 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 22.81it/s]
# epoch 017 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.45it/s]
#                                                                                 2022-08-05 15:19:28 | INFO | valid | epoch 017 | valid on 'valid' subset | loss 6.697 | nll_loss 5.159 | ppl 35.73 | wps 114391 | wpb 3283.1 | bsz 145.8 | num_updates 30747 | best_loss 6.42
# 2022-08-05 15:19:28 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 17 @ 30747 updates
# 2022-08-05 15:19:28 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint17.pt
# 2022-08-05 15:19:30 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint17.pt
# 2022-08-05 15:19:31 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint17.pt (epoch 17 @ 30747 updates, score 6.697) (writing took 3.260945708025247 seconds)
# 2022-08-05 15:19:31 | INFO | fairseq_cli.train | end of epoch 17 (average epoch stats below)
# 2022-08-05 15:19:31 | INFO | train | epoch 017 | loss 4.922 | nll_loss 3.21 | ppl 9.25 | wps 58611 | ups 8.61 | wpb 6809.5 | bsz 243.4 | num_updates 30747 | lr 0.000255043 | gnorm 0.69 | clip 5.2 | loss_scale 4 | train_wall 203 | gb_free 39.1 | wall 3688
# 2022-08-05 15:19:31 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 018:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:19:31 | INFO | fairseq.trainer | begin training epoch 18
# 2022-08-05 15:19:31 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 018: 100%|▉| 1807/1809 [03:24<00:00,  8.86it/s, loss=4.889, nll_loss=3.1732022-08-05 15:22:56 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 018 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 018 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 23.52it/s]
# epoch 018 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.82it/s]
#                                                                                 2022-08-05 15:22:56 | INFO | valid | epoch 018 | valid on 'valid' subset | loss 6.557 | nll_loss 5.003 | ppl 32.06 | wps 115324 | wpb 3283.1 | bsz 145.8 | num_updates 32556 | best_loss 6.42
# 2022-08-05 15:22:56 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 18 @ 32556 updates
# 2022-08-05 15:22:56 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint18.pt
# 2022-08-05 15:22:58 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint18.pt
# 2022-08-05 15:23:00 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint18.pt (epoch 18 @ 32556 updates, score 6.557) (writing took 3.267165750032291 seconds)
# 2022-08-05 15:23:00 | INFO | fairseq_cli.train | end of epoch 18 (average epoch stats below)
# 2022-08-05 15:23:00 | INFO | train | epoch 018 | loss 4.883 | nll_loss 3.164 | ppl 8.96 | wps 59081.6 | ups 8.68 | wpb 6809.5 | bsz 243.4 | num_updates 32556 | lr 0.000247856 | gnorm 0.7 | clip 5.1 | loss_scale 4 | train_wall 201 | gb_free 39.3 | wall 3897
# 2022-08-05 15:23:00 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 019:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:23:00 | INFO | fairseq.trainer | begin training epoch 19
# 2022-08-05 15:23:00 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 019: 100%|▉| 1808/1809 [03:24<00:00,  8.79it/s, loss=4.852, nll_loss=3.1292022-08-05 15:26:25 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 019 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 019 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 23.65it/s]
# epoch 019 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.88it/s]
#                                                                                 2022-08-05 15:26:25 | INFO | valid | epoch 019 | valid on 'valid' subset | loss 6.59 | nll_loss 5.037 | ppl 32.84 | wps 117373 | wpb 3283.1 | bsz 145.8 | num_updates 34365 | best_loss 6.42
# 2022-08-05 15:26:25 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 19 @ 34365 updates
# 2022-08-05 15:26:25 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint19.pt
# 2022-08-05 15:26:27 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint19.pt
# 2022-08-05 15:26:28 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint19.pt (epoch 19 @ 34365 updates, score 6.59) (writing took 3.2498313498217613 seconds)
# 2022-08-05 15:26:28 | INFO | fairseq_cli.train | end of epoch 19 (average epoch stats below)
# 2022-08-05 15:26:28 | INFO | train | epoch 019 | loss 4.846 | nll_loss 3.12 | ppl 8.69 | wps 59050.1 | ups 8.67 | wpb 6809.5 | bsz 243.4 | num_updates 34365 | lr 0.000241244 | gnorm 0.703 | clip 5.5 | loss_scale 4 | train_wall 201 | gb_free 39.9 | wall 4105
# 2022-08-05 15:26:29 | INFO | fairseq.data.iterators | grouped total_num_itrs = 1809
# epoch 020:   0%|                                       | 0/1809 [00:00<?, ?it/s]2022-08-05 15:26:29 | INFO | fairseq.trainer | begin training epoch 20
# 2022-08-05 15:26:29 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 020: 100%|▉| 1808/1809 [03:23<00:00,  9.08it/s, loss=4.871, nll_loss=3.1482022-08-05 15:29:53 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 020 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 020 | valid on 'valid' subset:  38%|███     | 3/8 [00:00<00:00, 23.59it/s]
# epoch 020 | valid on 'valid' subset:  88%|███████ | 7/8 [00:00<00:00, 29.89it/s]
#                                                                                 2022-08-05 15:29:53 | INFO | valid | epoch 020 | valid on 'valid' subset | loss 6.547 | nll_loss 4.985 | ppl 31.67 | wps 116123 | wpb 3283.1 | bsz 145.8 | num_updates 36174 | best_loss 6.42
# 2022-08-05 15:29:53 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 20 @ 36174 updates
# 2022-08-05 15:29:53 | INFO | fairseq.trainer | Saving checkpoint to /workspace/data/ch10/91_trained/checkpoint20.pt
# 2022-08-05 15:29:55 | INFO | fairseq.trainer | Finished saving checkpoint to /workspace/data/ch10/91_trained/checkpoint20.pt
# 2022-08-05 15:29:56 | INFO | fairseq.checkpoint_utils | Saved checkpoint ../data/ch10/91_trained/checkpoint20.pt (epoch 20 @ 36174 updates, score 6.547) (writing took 3.26086542988196 seconds)
# 2022-08-05 15:29:56 | INFO | fairseq_cli.train | end of epoch 20 (average epoch stats below)
# 2022-08-05 15:29:56 | INFO | train | epoch 020 | loss 4.812 | nll_loss 3.08 | ppl 8.45 | wps 59261.5 | ups 8.7 | wpb 6809.5 | bsz 243.4 | num_updates 36174 | lr 0.000235135 | gnorm 0.713 | clip 5.7 | loss_scale 4 | train_wall 200 | gb_free 39.4 | wall 4313
# 2022-08-05 15:29:56 | INFO | fairseq_cli.train | done training in 4313.0 seconds
